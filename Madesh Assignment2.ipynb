# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sb

# %%
import pandas

# %%
from bs4 import BeautifulSoup

# %%
mb=pandas.read_csv("C:\\Users\\aedpu\\Downloads\\List of largest Internet companies.csv")

# %%
mb
# Out:
#      Unnamed: 0  Rank             Company RevenueUSD billions  F.Y. Employees  \
# 0             0     1              Amazon             $469.82  2021   1608000
# 1             1     2            Alphabet             $257.64  2021    156500
# 2             2     3              JD.com             $149.32  2021    385357
# 3             3     4                Meta             $117.93  2021     71970
# 4             4     5             Alibaba             $109.48  2021    251462
# ..          ...   ...                 ...                 ...   ...       ...
# 101         101   101             LogMeIn               $1.26  2019      3974
# 102         102   102  Unity Technologies                $1.2  2021      5500
# 103         103   103         Blue Yonder                $1.1  2021      5500
# 104         104   104          Craigslist                $1.0  2018      1000
# 105         105   105                Grab                $1.0  2018      6000
#
# ...

# %%
mpp=mb.tail()

# %%
mpp
# Out:
#      Unnamed: 0  Rank             Company RevenueUSD billions  F.Y. Employees  \
# 101         101   101             LogMeIn               $1.26  2019      3974
# 102         102   102  Unity Technologies                $1.2  2021      5500
# 103         103   103         Blue Yonder                $1.1  2021      5500
# 104         104   104          Craigslist                $1.0  2018      1000
# 105         105   105                Grab                $1.0  2018      6000
#
#     Market cap.USD billions         Headquarters  Founded         Industry
# 101                   $4.21               Boston     2003         Software
# 102                  $12.73        San Francisco     2004  Software gaming
# 103                       -  Scottsdale, Arizona     1985         Software
# 104                       -        San Francisco     1995      Classifieds
# 105                       -            Singapore     2012   Transportation

# %%
plt.scatter(mpp['Rank'],mpp['Employees'])

# %%
plt.bar(mb['Founded'],mb['F.Y.'])
# Out:
# <BarContainer object of 106 artists>

# %%
plt.plot(mb['F.Y.'],mb['Founded'],linestyle='dotted')

# %%
mpp=mb.tail()

# %%
mpp
# Out:
#      Unnamed: 0  Rank             Company RevenueUSD billions  F.Y. Employees  \
# 101         101   101             LogMeIn               $1.26  2019      3974
# 102         102   102  Unity Technologies                $1.2  2021      5500
# 103         103   103         Blue Yonder                $1.1  2021      5500
# 104         104   104          Craigslist                $1.0  2018      1000
# 105         105   105                Grab                $1.0  2018      6000
#
#     Market cap.USD billions         Headquarters  Founded         Industry
# 101                   $4.21               Boston     2003         Software
# 102                  $12.73        San Francisco     2004  Software gaming
# 103                       -  Scottsdale, Arizona     1985         Software
# 104                       -        San Francisco     1995      Classifieds
# 105                       -            Singapore     2012   Transportation

# %%
plt.pie(mpp['Rank'],labels=mpp['F.Y.'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2059f71b8b0>,
# ...
#  [Text(0.8977405736262011, 0.635658605279044, '2019'),
#   Text(-0.30785665059779654, 1.056041799685366, '2021'),
#   Text(-1.0992632804942815, 0.040252206858147115, '2021'),
#   Text(-0.37166454318775793, -1.0353093582775321, '2018'),
#   Text(0.8819643401705983, -0.657372727352939, '2018')])

# %% [markdown]
# # seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sbn

# %%
import numpy as np

# %%
time=np.arange(0,1000,0.5)

# %%
time
# Out:
# array([0.000e+00, 5.000e-01, 1.000e+00, ..., 9.985e+02, 9.990e+02,
#        9.995e+02])

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.47942554,  0.84147098, ..., -0.50247916,
#        -0.02646075,  0.45603617])

# %%
plt.plot(time,amplitude)

# %%
plt.plot(mpp['Rank'],mpp['Employees'])

# %%
sb.set(style='darkgrid')

# %%
sb.distplot(mpp['Rank'])
# Out:
# C:\Users\aedpu\AppData\Local\Temp\ipykernel_7880\3196678416.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(mpp['Rank'])
# <Axes: xlabel='Rank', ylabel='Density'>

# %%
mpp
# Out:
#      Unnamed: 0  Rank             Company RevenueUSD billions  F.Y. Employees  \
# 101         101   101             LogMeIn               $1.26  2019      3974
# 102         102   102  Unity Technologies                $1.2  2021      5500
# 103         103   103         Blue Yonder                $1.1  2021      5500
# 104         104   104          Craigslist                $1.0  2018      1000
# 105         105   105                Grab                $1.0  2018      6000
#
#     Market cap.USD billions         Headquarters  Founded         Industry
# 101                   $4.21               Boston     2003         Software
# 102                  $12.73        San Francisco     2004  Software gaming
# 103                       -  Scottsdale, Arizona     1985         Software
# 104                       -        San Francisco     1995      Classifieds
# 105                       -            Singapore     2012   Transportation

# %%
sb.relplot(x='F.Y.',y='Rank',data=mpp,col='F.Y.',hue="Founded",style='Founded',kind="scatter")

# %%
sb.catplot(x='F.Y.',y='Founded',kind='box',data=mb)

# %%
sb.regplot(x='Rank',y='Founded',data=mb)
# Out:
# <Axes: xlabel='Rank', ylabel='Founded'>

# %%
sb.pairplot(mb)

# %%
sb.pairplot(mb,hue='Employees',palette='Set1')
