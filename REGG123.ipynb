# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("C:\\Users\\admin\\Documents\\Madesh\\Admission_Predict.csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
GA.shape
# Out:
# (400, 9)

# %%
newdataset=GA.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','SOP','University Rating','CGPA','Research'],axis=1)

# %%
newdataset
# Out:
#      LOR   Chance of Admit
# 0     4.5              0.92
# 1     4.5              0.76
# 2     3.5              0.72
# 3     2.5              0.80
# 4     3.0              0.65
# ..    ...               ...
# 395   3.5              0.82
# 396   3.5              0.84
# 397   4.5              0.91
# 398   4.0              0.67
# 399   4.0              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[4.5],
#        [4.5],
#        [3.5],
#        [2.5],
#        [3. ],
#        [3. ],
#        [4. ],
#        [4. ],
#        [1.5],
#        [3. ],
#        [4. ],
#        [4.5],
#        [4.5],
#        [3. ],
#        [2. ],
#        [2.5],
#        [3. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [2. ],
#        [2. ],
#        [5. ],
#        [4.5],
#        [3.5],
#        [4.5],
#        [3.5],
#        [2.5],
#        [2. ],
#        [2. ],
#        [3. ],
#        [4. ],
#        [4.5],
#        [4. ],
#        [5. ],
#        [5. ],
#        [4. ],
#        [2. ],
#        [1.5],
#        [3.5],
#        [3. ],
#        [2.5],
#        [2. ],
#        [4. ],
#        [4. ],
#        [4. ],
#        [5. ],
#        [4. ],
#        [5. ],
#        [4. ],
#        [4.5],
#        [3.5],
#        [3. ],
#        [2.5],
#        [3.5],
#        [3. ],
#        [3. ],
#        [2. ],
#        [2. ],
#        [2. ],
#        [3. ],
#        [3. ],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('LOR')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_test.shape
# Out:
# (120, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
x_train
# Out:
# array([[3. ],
#        [4. ],
#        [4. ],
#        [3.5],
#        [2. ],
#        [3.5],
#        [5. ],
#        [3.5],
#        [3.5],
#        [4. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [3.5],
#        [3. ],
#        [4. ],
#        [3. ],
#        [2. ],
#        [3. ],
#        [4. ],
#        [3. ],
#        [3. ],
#        [3. ],
#        [1.5],
#        [4. ],
#        [2. ],
#        [2.5],
#        [4. ],
#        [3.5],
#        [3. ],
#        [5. ],
#        [3.5],
#        [3.5],
#        [4.5],
#        [4. ],
#        [3. ],
#        [3. ],
#        [4.5],
#        [3.5],
#        [4.5],
#        [4.5],
#        [4. ],
#        [2.5],
#        [3. ],
#        [5. ],
#        [2.5],
#        [4. ],
#        [3.5],
#        [3. ],
#        [3. ],
#        [3.5],
#        [3. ],
#        [3. ],
#        [4.5],
#        [4.5],
#        [5. ],
#        [5. ],
#        [3.5],
#        [3.5],
#        [2. ],
#        [4. ],
# ...

# %%
y_train
# Out:
# array([[0.34],
#        [0.71],
#        [0.91],
#        [0.69],
#        [0.47],
#        [0.92],
#        [0.94],
#        [0.71],
#        [0.74],
#        [0.64],
#        [0.93],
#        [0.77],
#        [0.61],
#        [0.6 ],
#        [0.84],
#        [0.64],
#        [0.84],
#        [0.77],
#        [0.63],
#        [0.65],
#        [0.81],
#        [0.84],
#        [0.65],
#        [0.59],
#        [0.7 ],
#        [0.57],
#        [0.7 ],
#        [0.81],
#        [0.88],
#        [0.56],
#        [0.8 ],
#        [0.94],
#        [0.79],
#        [0.62],
#        [0.93],
#        [0.76],
#        [0.78],
#        [0.85],
#        [0.7 ],
#        [0.71],
#        [0.8 ],
#        [0.79],
#        [0.9 ],
#        [0.56],
#        [0.67],
#        [0.94],
#        [0.74],
#        [0.86],
#        [0.76],
#        [0.47],
#        [0.64],
#        [0.81],
#        [0.73],
#        [0.71],
#        [0.73],
#        [0.89],
#        [0.93],
#        [0.86],
# ...

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[0.72569693],
#        [0.67083701],
#        [0.72569693],
#        [0.61597709],
#        [0.72569693],
#        [0.67083701],
#        [0.67083701],
#        [0.78055685],
#        [0.72569693],
#        [0.89027668],
#        [0.56111718],
#        [0.78055685],
#        [0.72569693],
#        [0.56111718],
#        [0.83541676],
#        [0.56111718],
#        [0.67083701],
#        [0.67083701],
#        [0.67083701],
#        [0.83541676],
#        [0.83541676],
#        [0.89027668],
#        [0.67083701],
#        [0.56111718],
#        [0.72569693],
#        [0.67083701],
#        [0.56111718],
#        [0.61597709],
#        [0.78055685],
#        [0.72569693],
#        [0.72569693],
#        [0.72569693],
#        [0.78055685],
#        [0.61597709],
#        [0.72569693],
#        [0.67083701],
#        [0.78055685],
#        [0.83541676],
#        [0.67083701],
#        [0.78055685],
#        [0.72569693],
#        [0.78055685],
#        [0.78055685],
# ...

# %%
COMP=pd.DataFrame(x_test,columns=['LOR'])

# %%
COMP
# Out:
#      LOR
# 0    3.5
# 1    3.0
# 2    3.5
# 3    2.5
# 4    3.5
# ..   ...
# 115  4.5
# 116  4.5
# 117  4.0
# 118  3.5
# 119  3.5
#
# [120 rows x 1 columns]

# %%
COMP['AVLDATA']=y_test

# %%
COMP
# Out:
#      LOR  AVLDATA
# 0    3.5     0.71
# 1    3.0     0.70
# 2    3.5     0.79
# 3    2.5     0.73
# 4    3.5     0.72
# ..   ...      ...
# 115  4.5     0.91
# 116  4.5     0.90
# 117  4.0     0.78
# 118  3.5     0.70
# 119  3.5     0.59
#
# [120 rows x 2 columns]

# %%
COMP['PREDATA']=y_predict

# %%
COMP
# Out:
#      LOR  AVLDATA   PREDATA
# 0    3.5     0.71  0.725697
# 1    3.0     0.70  0.670837
# 2    3.5     0.79  0.725697
# 3    2.5     0.73  0.615977
# 4    3.5     0.72  0.725697
# ..   ...      ...       ...
# 115  4.5     0.91  0.835417
# 116  4.5     0.90  0.835417
# 117  4.0     0.78  0.780557
# 118  3.5     0.70  0.725697
# 119  3.5     0.59  0.725697
#
# [120 rows x 3 columns]

# %%
pt.scatter(x,y,color='red')
pt.plot(x_test,y_predict,color='black')
pt.xlabel('LOR')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.08124631403937901
